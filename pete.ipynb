# %% [markdown]
# # Import Modules

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from utils import *
from sklearn.preprocessing import MinMaxScaler

sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.dpi'] = 110

# %%
# 3 Datasets
df_statlog_framingham_stroke_intersection = get_combined("statlog-framingham-stroke-intersection")
df_statlog_framingham_stroke_union = get_combined("statlog-framingham-stroke-union")
df_statlog_heart_stroke_intersection = get_combined("statlog-heart-stroke-intersection")
df_statlog_heart_stroke_union = get_combined("statlog-heart-stroke-union")

# 2 Datasets
df_framingham_stroke_intersection = get_combined("framingham-stroke-intersection")
df_framingham_stroke_union = get_combined("framingham-stroke-union")
df_heart_stroke_intersection = get_combined("heart-stroke-intersection")
df_heart_stroke_union = get_combined("heart-stroke-union")

# %% [markdown]
# # Data Preprocessing
